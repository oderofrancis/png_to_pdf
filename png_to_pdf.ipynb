# %%
from PIL import Image

# %%
image = Image.open('/content/drive/MyDrive/Colab Notebooks/resume_cv.png')

# %%
image = image.convert('RGB')

# %%
image.save('/content/drive/MyDrive/Colab Notebooks/resume.pdf')
